# %%
#Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 300

# %%
# Load Dataset

df = pd.read_csv("D:\ExcelR\Data Science\Assignments\Simple Linear Regression\Salary_Data.csv")
df.head()
# Out:
#    Experience  Salary
# 0         1.1   39343
# 1         1.3   46205
# 2         1.5   37731
# 3         2.0   43525
# 4         2.2   39891

# %%
df.describe()
# Out:
#        Experience         Salary
# count   30.000000      30.000000
# mean     5.313333   76003.000000
# std      2.837888   27414.429785
# min      1.100000   37731.000000
# 25%      3.200000   56720.750000
# 50%      4.700000   65237.000000
# 75%      7.700000  100544.750000
# max     10.500000  122391.000000

# %%
df.isna().sum()
# Out:
# Experience    0
# Salary        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Experience    0
# Salary        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Experience  30 non-null     float64
#  1   Salary      30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
plt.scatter(df['Experience'], df['Salary'])
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Years of Experience vs. Salary')
# Out:
# Text(0.5, 1.0, 'Years of Experience vs. Salary')

# %%
sns.distplot(df['Experience'])
# Out:
# <Axes: xlabel='Experience', ylabel='Density'>

# %%
sns.distplot(df['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
# Define x and y

x = df['Experience'].values.reshape(-1, 1)

y = df['Salary'].values

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872], dtype=int64)

# %%
# Spliting data into traning and testing
# import necessary libraries for this process

from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
# Import necessary library for Regression

from sklearn.linear_model import LinearRegression

# %%
LinReg = LinearRegression()

# %%
LinReg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_predict = LinReg.predict(xtest)
y_predict
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %%
from sklearn.metrics import r2_score

print(f"r2 Score :", r2_score(ytest, y_predict))
# Out:
# r2 Score : 0.988169515729126

# %%
plt.scatter(xtest, ytest, color='blue')
plt.plot(xtest, y_predict, color='red', linewidth=2)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Linear Regression: Years of Experience vs. Salary')
plt.show()
