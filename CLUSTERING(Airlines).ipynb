# %%
# Import Necesary Libraries

import pandas as pd
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
#Load Dataset

df = pd.read_csv("D:\ExcelR\Data Science\Assignments\Clustering\Airlines_data.csv")
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  3995    18476           0          1          1          1         8525
# 3995  3996    64385           0          1          1          1          981
# 3996  3997    73597           0          3          1          1        25447
# 3997  3998    54899           0          1          1          1          500
# 3998  3999     3016           0          1          1          1            0
#
# ...

# %%
df1 = df.drop(columns='ID#')

# %%
from sklearn.preprocessing import normalize

df1_norm = pd.DataFrame(normalize(df1), columns = df1.columns)
df1_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Hierarchical Clustering

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 300

# %%
# Dendrogram
dendrogram = sch.dendrogram(sch.linkage(df1_norm, method='complete'))

# Visualize the dendrogram
plt.title('Dendrogram')
plt.xlabel('Passengers')
plt.ylabel('Euclidean Distances')
# Out:
# Text(0, 0.5, 'Euclidean Distances')

# %%
from sklearn.cluster import AgglomerativeClustering

hclusters = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
hclusters
# Out:
# AgglomerativeClustering(affinity='euclidean', n_clusters=5)

# %%
y = pd.DataFrame(hclusters.fit_predict(df1_norm), columns=['Clusters'])
y['Clusters'].value_counts()
# Out:
# 2    1547
# 4    1191
# 3     579
# 1     453
# 0     229
# Name: Clusters, dtype: int64

# %%
df1['Clusters'] = hclusters.labels_
df1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df1.groupby('Clusters').agg(['mean']).reset_index()
# Out:
#   Clusters       Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                     mean        mean      mean      mean      mean
# 0        0   5524.222707    8.755459  1.000000  1.000000  1.000000
# 1        1  31066.514349  111.415011  3.200883  1.026490  1.070640
# 2        2  81201.080802  136.521008  2.115061  1.013575  1.000646
# 3        3  69569.894646   97.257340  3.326425  1.032815  1.022453
# 4        4  94957.590260  215.220823  1.141058  1.005038  1.002519
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0    584.532751    2.401747         66.982533        0.209607
# 1  40266.935982   17.289183        626.754967        1.812362
# 2  16350.149968   13.574014        488.550743        1.340659
# 3  35743.675302   17.784111        406.804836        1.274611
# 4   3524.928631    5.640638        461.104954        1.521411
#
#   Days_since_enroll    Award?
# ...

# %%
plt.figure(figsize=(10,7))
plt.scatter(df1['Clusters'], df1['Balance'], c = hclusters.labels_)

# %% [markdown]
# ### K-Means Clustering

# %%
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

df2 = df.copy()
df2 = df2.drop(columns='ID#')
df2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
def norm_func(i):
    x=(i-i.min())/(i.max()-i.min())
    return(x)

# %%
df
df2_norm = norm_func(df2)

# %%
wcss=[]

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df2_norm)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('Elbow curv')
plt.xlabel('number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
model = KMeans(n_clusters=4)
model.fit(df2_norm)
model.labels_
# Out:
# array([0, 0, 0, ..., 3, 0, 0])

# %%
x = pd.Series(model.labels_)
df2['Cluster'] = x
df2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df2.iloc[:,1:5].groupby(df2.Cluster).mean()
# Out:
#          Qual_miles  cc1_miles  cc2_miles  cc3_miles
# Cluster
# 0         92.345809   1.092778   1.017923   1.004217
# 1        290.453195   1.156018   1.032689   1.008915
# 2         73.112721   3.576490   1.001610   1.022544
# 3        198.336634   3.915842   1.001238   1.025990

# %% [markdown]
# ### DBSCAN Clustering

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

df3 = df.copy()
df3 = df3.drop(columns='ID#')
df3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
sc = StandardScaler()
df3_scaled = sc.fit_transform(df3)
df3_scaled
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
dbscan = DBSCAN(eps=2,min_samples=5)
dbscan.fit(df3_scaled)
# Out:
# DBSCAN(eps=2)

# %%
df3['Clusters'] = dbscan.labels_
df3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...
